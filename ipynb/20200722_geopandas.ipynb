# %% [markdown]
# [How to plot US Maps using GeoPandas](https://jcutrer.com/python/learn-geopandas-plotting-usmaps)
#
# [Mapa estático de España con Python](https://analisisydecision.es/mapa-estatico-de-espana-con-python/)

# %%
import matplotlib.pyplot as plt
import geopandas

# %%
spain = geopandas.read_file('../data/gadm36_ESP_shp/gadm36_ESP_2.shp')
type(spain)
# Out:
# geopandas.geodataframe.GeoDataFrame

# %%
spain.head()
# Out:
#   GID_0 NAME_0    GID_1     NAME_1 NL_NAME_1      GID_2   NAME_2 VARNAME_2  \
# 0   ESP  Spain  ESP.1_1  Andalucía      None  ESP.1.1_1  Almería      None
# 1   ESP  Spain  ESP.1_1  Andalucía      None  ESP.1.2_1    Cádiz      None
# 2   ESP  Spain  ESP.1_1  Andalucía      None  ESP.1.3_1  Córdoba      None
# 3   ESP  Spain  ESP.1_1  Andalucía      None  ESP.1.4_1  Granada      None
# 4   ESP  Spain  ESP.1_1  Andalucía      None  ESP.1.5_1   Huelva      None
#
#   NL_NAME_2     TYPE_2 ENGTYPE_2 CC_2    HASC_2  \
# 0      None  Provincia  Province   04  ES.AN.AM
# 1      None  Provincia  Province   11  ES.AN.CD
# 2      None  Provincia  Province   14  ES.AN.CO
# 3      None  Provincia  Province   18  ES.AN.GD
# 4      None  Provincia  Province   21  ES.AN.HL
#
#                                             geometry
# 0  MULTIPOLYGON (((-3.03042 35.94236, -3.03042 35...
# 1  MULTIPOLYGON (((-6.21958 36.38110, -6.21958 36...
# 2  MULTIPOLYGON (((-5.04854 37.63690, -5.04667 37...
# ...

# %%
spain.crs
# Out:
# <Geographic 2D CRS: EPSG:4326>
# Name: WGS 84
# Axis Info [ellipsoidal]:
# - Lat[north]: Geodetic latitude (degree)
# - Lon[east]: Geodetic longitude (degree)
# Area of Use:
# - name: World
# - bounds: (-180.0, -90.0, 180.0, 90.0)
# Datum: World Geodetic System 1984
# - Ellipsoid: WGS 84
# - Prime Meridian: Greenwich

# %%
spain.plot();

# %%
spain = spain.to_crs("EPSG:3395")

# %%
spain.crs
# Out:
# <Projected CRS: EPSG:3395>
# Name: WGS 84 / World Mercator
# Axis Info [cartesian]:
# - E[east]: Easting (metre)
# - N[north]: Northing (metre)
# Area of Use:
# - name: World - between 80°S and 84°N
# - bounds: (-180.0, -80.0, 180.0, 84.0)
# Coordinate Operation:
# - name: World Mercator
# - method: Mercator (variant A)
# Datum: World Geodetic System 1984
# - Ellipsoid: WGS 84
# - Prime Meridian: Greenwich

# %%
spain.plot();

# %%
spain.boundary.plot();

# %%
spain.boundary.plot(cmap='tab10', figsize=(14, 12));
